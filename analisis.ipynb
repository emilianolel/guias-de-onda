# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
perfil_incidencia_11 = pd.read_csv("data/perfil_incidente_11.csv")
perfil_incidencia_31 = pd.read_csv("data/perfil_incidente_31.csv")
perfil_incidencia_61 = pd.read_csv("data/perfil_incidente_61.csv")
perfil_reflejado_11 = pd.read_csv("data/perfil_incidente_11.csv")
perfil_reflejado_31 = pd.read_csv("data/perfil_reflejado_31.csv")
perfil_reflejado_61 = pd.read_csv("data/perfil_reflejado_61.csv")

# %%
# fig, axes = plt.subplots(nrows=1, ncols=3)
# fig.suptitle('Perfiles de Intensidad Incidentes para Concentraciones 1:1, 3:1 y 6:1')
perfil_incidencia_11.plot.scatter(x="x",
                                  y="luma",
                                  grid=True,
                                  title="Perfil de Intensidad Incidente para Concentración\ngrenetina/agua 1:1",
                                  ylabel="Intensidad Lumínica",
                                  xlabel="Posición [cm]")
perfil_incidencia_31.plot.scatter(x="x",
                                  y="luma",
                                  grid=True,
                                  title="Perfil de Intensidad Incidente para Concentración\ngrenetina/agua 3:1",
                                  ylabel="Intensidad Lumínica",
                                  xlabel="Posición [cm]")
perfil_incidencia_61.plot.scatter(x="x",
                                  y="luma",
                                  grid=True,
                                  title="Perfil de Intensidad Incidente para Concentración\ngrenetina/agua 6:1",
                                  ylabel="Intensidad Lumínica",
                                  xlabel="Posición [cm]")
# Out:
# <AxesSubplot:title={'center':'Perfil de Intensidad Incidente para Concentración\ngrenetina/agua 6:1'}, xlabel='Posición [cm]', ylabel='Intensidad Lumínica'>

# %%
perfil_reflejado_11.plot.scatter(x="x",
                                 y="luma",
                                 grid=True,
                                 title="Perfil de Intensidad Reflejado para Concentración\ngrenetina/agua 1:1",
                                 ylabel="Intensidad Lumínica",
                                 xlabel="Posición [cm]")
perfil_reflejado_31.plot.scatter(x="x",
                                 y="luma",
                                 grid=True,
                                 title="Perfil de Intensidad Reflejado para Concentración\ngrenetina/agua 3:1",
                                 ylabel="Intensidad Lumínica",
                                xlabel="Posición [cm]")
perfil_reflejado_61.plot.scatter(x="x",
                                 y="luma",
                                 grid=True,
                                 title="Perfil de Intensidad Reflejado para Concentración\ngrenetina/agua 6:1",
                                 ylabel="Intensidad Lumínica",
                                 xlabel="Posición [cm]")
# Out:
# <AxesSubplot:title={'center':'Perfil de Intensidad Reflejado para Concentración\ngrenetina/agua 6:1'}, xlabel='Posición [cm]', ylabel='Intensidad Lumínica'>
